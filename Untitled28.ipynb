# %% [markdown]
# <a href="https://colab.research.google.com/github/kemaleddin111/dd/blob/master/Untitled28.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -r faces
# !wget https://github.com/kemaleddin111/img/raw/master/fcc.zip
# !wget https://github.com/kemaleddin111/dd/raw/master/uretici.pkl
# !wget https://github.com/kemaleddin111/dd/raw/master/ayirt_edici.pkl
# !unzip fcc.zip
# Out:
# --2020-01-04 15:51:35--  https://github.com/kemaleddin111/img/raw/master/fcc.zip
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/kemaleddin111/img/master/fcc.zip [following]
# --2020-01-04 15:51:35--  https://raw.githubusercontent.com/kemaleddin111/img/master/fcc.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 45749989 (44M) [application/zip]
# Saving to: ‘fcc.zip.1’
#
# fcc.zip.1           100%[===================>]  43.63M   228MB/s    in 0.2s
#
# 2020-01-04 15:51:36 (228 MB/s) - ‘fcc.zip.1’ saved [45749989/45749989]
#
# --2020-01-04 15:51:37--  https://github.com/kemaleddin111/dd/raw/master/uretici.pkl
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://media.githubusercontent.com/media/kemaleddin111/dd/master/uretici.pkl [following]
# --2020-01-04 15:51:37--  https://media.githubusercontent.com/media/kemaleddin111/dd/master/uretici.pkl
# Resolving media.githubusercontent.com (media.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to media.githubusercontent.com (media.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 217733408 (208M) [application/octet-stream]
# Saving to: ‘uretici.pkl.1’
#
# uretici.pkl.1       100%[===================>] 207.65M   200MB/s    in 1.0s
#
# 2020-01-04 15:51:43 (200 MB/s) - ‘uretici.pkl.1’ saved [217733408/217733408]
#
# --2020-01-04 15:51:44--  https://github.com/kemaleddin111/dd/raw/master/ayirt_edici.pkl
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/kemaleddin111/dd/master/ayirt_edici.pkl [following]
# --2020-01-04 15:51:44--  https://raw.githubusercontent.com/kemaleddin111/dd/master/ayirt_edici.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11089357 (11M) [application/octet-stream]
# Saving to: ‘ayirt_edici.pkl.1’
#
# ayirt_edici.pkl.1   100%[===================>]  10.58M  63.2MB/s    in 0.2s
#
# 2020-01-04 15:51:44 (63.2 MB/s) - ‘ayirt_edici.pkl.1’ saved [11089357/11089357]
#
# Archive:  fcc.zip
#    creating: faces/
#    creating: faces/arama/
#    creating: faces/arama/arama_resimleri/
#   inflating: faces/arama/arama_resimleri/2222.jpg
#   inflating: faces/arama/arama_resimleri/574.jpg
#   inflating: faces/arama/arama_resimleri/mic.jpg
#   inflating: faces/arama/arama_resimleri/test4.jpg
#   inflating: faces/arama/arama_resimleri/222.jpg
#    creating: faces/img_dataset/
#    creating: faces/img_dataset/train/
#   inflating: faces/img_dataset/train/619.jpg
#   inflating: faces/img_dataset/train/510.jpg
#   inflating: faces/img_dataset/train/540.jpg
#   inflating: faces/img_dataset/train/536.jpg
#   inflating: faces/img_dataset/train/812.jpg
#   inflating: faces/img_dataset/train/723.jpg
#   inflating: faces/img_dataset/train/230.jpg
#   inflating: faces/img_dataset/train/172.jpg
#   inflating: faces/img_dataset/train/512.jpg
#   inflating: faces/img_dataset/train/3.jpg
#   inflating: faces/img_dataset/train/281.jpg
#   inflating: faces/img_dataset/train/719.jpg
#   inflating: faces/img_dataset/train/258.jpg
#   inflating: faces/img_dataset/train/830.jpg
#   inflating: faces/img_dataset/train/543.jpg
#   inflating: faces/img_dataset/train/640.jpg
#   inflating: faces/img_dataset/train/588.jpg
#   inflating: faces/img_dataset/train/780.jpg
#   inflating: faces/img_dataset/train/615.jpg
#   inflating: faces/img_dataset/train/212.jpg
#   inflating: faces/img_dataset/train/477.jpg
#   inflating: faces/img_dataset/train/22.jpg
#   inflating: faces/img_dataset/train/629.jpg
#   inflating: faces/img_dataset/train/751.jpg
#   inflating: faces/img_dataset/train/145.jpg
#   inflating: faces/img_dataset/train/596.jpg
#   inflating: faces/img_dataset/train/475.jpg
#   inflating: faces/img_dataset/train/119.jpg
#   inflating: faces/img_dataset/train/530.jpg
#   inflating: faces/img_dataset/train/83.jpg
#   inflating: faces/img_dataset/train/495.jpg
#   inflating: faces/img_dataset/train/800.jpg
#   inflating: faces/img_dataset/train/219.jpg
#   inflating: faces/img_dataset/train/79.jpg
#   inflating: faces/img_dataset/train/386.jpg
#   inflating: faces/img_dataset/train/184.jpg
#   inflating: faces/img_dataset/train/59.jpg
#   inflating: faces/img_dataset/train/516.jpg
#   inflating: faces/img_dataset/train/702.jpg
#   inflating: faces/img_dataset/train/693.jpg
#   inflating: faces/img_dataset/train/193.jpg
#   inflating: faces/img_dataset/train/298.jpg
#   inflating: faces/img_dataset/train/266.jpg
#   inflating: faces/img_dataset/train/51.jpg
#   inflating: faces/img_dataset/train/78.jpg
#   inflating: faces/img_dataset/train/464.jpg
#   inflating: faces/img_dataset/train/99.jpg
#   inflating: faces/img_dataset/train/810.jpg
#   inflating: faces/img_dataset/train/352.jpg
#   inflating: faces/img_dataset/train/381.jpg
#   inflating: faces/img_dataset/train/337.jpg
#   inflating: faces/img_dataset/train/763.jpg
#   inflating: faces/img_dataset/train/766.jpg
#   inflating: faces/img_dataset/train/425.jpg
#   inflating: faces/img_dataset/train/273.jpg
#   inflating: faces/img_dataset/train/578.jpg
#   inflating: faces/img_dataset/train/654.jpg
#   inflating: faces/img_dataset/train/182.jpg
#   inflating: faces/img_dataset/train/696.jpg
#   inflating: faces/img_dataset/train/346.jpg
#   inflating: faces/img_dataset/train/742.jpg
#   inflating: faces/img_dataset/train/415.jpg
#   inflating: faces/img_dataset/train/788.jpg
#   inflating: faces/img_dataset/train/188.jpg
#   inflating: faces/img_dataset/train/736.jpg
#   inflating: faces/img_dataset/train/725.jpg
#   inflating: faces/img_dataset/train/442.jpg
#   inflating: faces/img_dataset/train/558.jpg
#   inflating: faces/img_dataset/train/227.jpg
#   inflating: faces/img_dataset/train/646.jpg
#   inflating: faces/img_dataset/train/159.jpg
#   inflating: faces/img_dataset/train/828.jpg
#   inflating: faces/img_dataset/train/824.jpg
#   inflating: faces/img_dataset/train/61.jpg
#   inflating: faces/img_dataset/train/132.jpg
#   inflating: faces/img_dataset/train/191.jpg
#   inflating: faces/img_dataset/train/320.jpg
#   inflating: faces/img_dataset/train/71.jpg
#   inflating: faces/img_dataset/train/897.jpg
#   inflating: faces/img_dataset/train/526.jpg
#   inflating: faces/img_dataset/train/440.jpg
#   inflating: faces/img_dataset/train/308.jpg
#   inflating: faces/img_dataset/train/248.jpg
#   inflating: faces/img_dataset/train/275.jpg
#   inflating: faces/img_dataset/train/777.jpg
#   inflating: faces/img_dataset/train/115.jpg
#   inflating: faces/img_dataset/train/492.jpg
#   inflating: faces/img_dataset/train/112.jpg
#   inflating: faces/img_dataset/train/610.jpg
#   inflating: faces/img_dataset/train/847.jpg
#   inflating: faces/img_dataset/train/91.jpg
#   inflating: faces/img_dataset/train/537.jpg
#   inflating: faces/img_dataset/train/93.jpg
#   inflating: faces/img_dataset/train/163.jpg
#   inflating: faces/img_dataset/train/575.jpg
#   inflating: faces/img_dataset/train/776.jpg
#   inflating: faces/img_dataset/train/194.jpg
#   inflating: faces/img_dataset/train/583.jpg
#   inflating: faces/img_dataset/train/153.jpg
#   inflating: faces/img_dataset/train/841.jpg
#   inflating: faces/img_dataset/train/214.jpg
#   inflating: faces/img_dataset/train/813.jpg
#   inflating: faces/img_dataset/train/717.jpg
#   inflating: faces/img_dataset/train/303.jpg
#   inflating: faces/img_dataset/train/504.jpg
#   inflating: faces/img_dataset/train/621.jpg
#   inflating: faces/img_dataset/train/126.jpg
#   inflating: faces/img_dataset/train/747.jpg
#   inflating: faces/img_dataset/train/882.jpg
#   inflating: faces/img_dataset/train/28.jpg
#   inflating: faces/img_dataset/train/623.jpg
#   inflating: faces/img_dataset/train/884.jpg
#   inflating: faces/img_dataset/train/378.jpg
#   inflating: faces/img_dataset/train/767.jpg
#   inflating: faces/img_dataset/train/183.jpg
#   inflating: faces/img_dataset/train/387.jpg
#   inflating: faces/img_dataset/train/798.jpg
#   inflating: faces/img_dataset/train/164.jpg
#   inflating: faces/img_dataset/train/755.jpg
#   inflating: faces/img_dataset/train/377.jpg
#   inflating: faces/img_dataset/train/849.jpg
#   inflating: faces/img_dataset/train/580.jpg
#   inflating: faces/img_dataset/train/41.jpg
#   inflating: faces/img_dataset/train/534.jpg
#   inflating: faces/img_dataset/train/215.jpg
#   inflating: faces/img_dataset/train/764.jpg
#   inflating: faces/img_dataset/train/292.jpg
#   inflating: faces/img_dataset/train/114.jpg
#   inflating: faces/img_dataset/train/653.jpg
#   inflating: faces/img_dataset/train/134.jpg
#   inflating: faces/img_dataset/train/843.jpg
#   inflating: faces/img_dataset/train/297.jpg
#   inflating: faces/img_dataset/train/282.jpg
#   inflating: faces/img_dataset/train/77.jpg
#   inflating: faces/img_dataset/train/160.jpg
#   inflating: faces/img_dataset/train/19.jpg
#   inflating: faces/img_dataset/train/204.jpg
#   inflating: faces/img_dataset/train/102.jpg
#   inflating: faces/img_dataset/train/2.jpg
#   inflating: faces/img_dataset/train/242.jpg
#   inflating: faces/img_dataset/train/280.jpg
#   inflating: faces/img_dataset/train/785.jpg
#   inflating: faces/img_dataset/train/592.jpg
#   inflating: faces/img_dataset/train/54.jpg
#   inflating: faces/img_dataset/train/637.jpg
#   inflating: faces/img_dataset/train/458.jpg
#   inflating: faces/img_dataset/train/605.jpg
#   inflating: faces/img_dataset/train/238.jpg
#   inflating: faces/img_dataset/train/323.jpg
#   inflating: faces/img_dataset/train/97.jpg
#   inflating: faces/img_dataset/train/743.jpg
#   inflating: faces/img_dataset/train/731.jpg
#   inflating: faces/img_dataset/train/336.jpg
#   inflating: faces/img_dataset/train/468.jpg
#   inflating: faces/img_dataset/train/391.jpg
#   inflating: faces/img_dataset/train/524.jpg
#   inflating: faces/img_dataset/train/519.jpg
#   inflating: faces/img_dataset/train/301.jpg
#   inflating: faces/img_dataset/train/406.jpg
#   inflating: faces/img_dataset/train/728.jpg
#   inflating: faces/img_dataset/train/574.jpg
#   inflating: faces/img_dataset/train/35.jpg
#   inflating: faces/img_dataset/train/694.jpg
#   inflating: faces/img_dataset/train/367.jpg
#   inflating: faces/img_dataset/train/803.jpg
#   inflating: faces/img_dataset/train/379.jpg
#   inflating: faces/img_dataset/train/237.jpg
#   inflating: faces/img_dataset/train/528.jpg
#   inflating: faces/img_dataset/train/316.jpg
#   inflating: faces/img_dataset/train/752.jpg
#   inflating: faces/img_dataset/train/744.jpg
#   inflating: faces/img_dataset/train/662.jpg
#   inflating: faces/img_dataset/train/689.jpg
#   inflating: faces/img_dataset/train/197.jpg
#   inflating: faces/img_dataset/train/774.jpg
#   inflating: faces/img_dataset/train/666.jpg
#   inflating: faces/img_dataset/train/120.jpg
#   inflating: faces/img_dataset/train/527.jpg
#   inflating: faces/img_dataset/train/498.jpg
#   inflating: faces/img_dataset/train/594.jpg
#   inflating: faces/img_dataset/train/753.jpg
#   inflating: faces/img_dataset/train/73.jpg
#   inflating: faces/img_dataset/train/435.jpg
#   inflating: faces/img_dataset/train/481.jpg
#   inflating: faces/img_dataset/train/32.jpg
#   inflating: faces/img_dataset/train/47.jpg
#   inflating: faces/img_dataset/train/569.jpg
#   inflating: faces/img_dataset/train/635.jpg
#   inflating: faces/img_dataset/train/862.jpg
#   inflating: faces/img_dataset/train/602.jpg
#   inflating: faces/img_dataset/train/449.jpg
#   inflating: faces/img_dataset/train/62.jpg
#   inflating: faces/img_dataset/train/627.jpg
#   inflating: faces/img_dataset/train/195.jpg
#   inflating: faces/img_dataset/train/533.jpg
#   inflating: faces/img_dataset/train/631.jpg
#   inflating: faces/img_dataset/train/839.jpg
#   inflating: faces/img_dataset/train/734.jpg
#   inflating: faces/img_dataset/train/836.jpg
#   inflating: faces/img_dataset/train/446.jpg
#   inflating: faces/img_dataset/train/625.jpg
#   inflating: faces/img_dataset/train/285.jpg
#   inflating: faces/img_dataset/train/203.jpg
#   inflating: faces/img_dataset/train/471.jpg
#   inflating: faces/img_dataset/train/590.jpg
#   inflating: faces/img_dataset/train/339.jpg
#   inflating: faces/img_dataset/train/459.jpg
#   inflating: faces/img_dataset/train/465.jpg
#   inflating: faces/img_dataset/train/262.jpg
#   inflating: faces/img_dataset/train/790.jpg
#   inflating: faces/img_dataset/train/657.jpg
#   inflating: faces/img_dataset/train/735.jpg
#   inflating: faces/img_dataset/train/416.jpg
#   inflating: faces/img_dataset/train/652.jpg
#   inflating: faces/img_dataset/train/226.jpg
#   inflating: faces/img_dataset/train/407.jpg
#   inflating: faces/img_dataset/train/213.jpg
#   inflating: faces/img_dataset/train/821.jpg
#   inflating: faces/img_dataset/train/252.jpg
#   inflating: faces/img_dataset/train/730.jpg
#   inflating: faces/img_dataset/train/626.jpg
#   inflating: faces/img_dataset/train/366.jpg
#   inflating: faces/img_dataset/train/42.jpg
#   inflating: faces/img_dataset/train/571.jpg
#   inflating: faces/img_dataset/train/349.jpg
#   inflating: faces/img_dataset/train/136.jpg
#   inflating: faces/img_dataset/train/831.jpg
#   inflating: faces/img_dataset/train/110.jpg
#   inflating: faces/img_dataset/train/656.jpg
#   inflating: faces/img_dataset/train/150.jpg
#   inflating: faces/img_dataset/train/342.jpg
#   inflating: faces/img_dataset/train/21.jpg
#   inflating: faces/img_dataset/train/858.jpg
#   inflating: faces/img_dataset/train/863.jpg
#   inflating: faces/img_dataset/train/676.jpg
#   inflating: faces/img_dataset/train/564.jpg
#   inflating: faces/img_dataset/train/250.jpg
#   inflating: faces/img_dataset/train/57.jpg
#   inflating: faces/img_dataset/train/315.jpg
#   inflating: faces/img_dataset/train/832.jpg
#   inflating: faces/img_dataset/train/185.jpg
#   inflating: faces/img_dataset/train/520.jpg
#   inflating: faces/img_dataset/train/622.jpg
#   inflating: faces/img_dataset/train/363.jpg
#   inflating: faces/img_dataset/train/695.jpg
#   inflating: faces/img_dataset/train/628.jpg
#   inflating: faces/img_dataset/train/739.jpg
#   inflating: faces/img_dataset/train/427.jpg
#   inflating: faces/img_dataset/train/517.jpg
#   inflating: faces/img_dataset/train/256.jpg
#   inflating: faces/img_dataset/train/294.jpg
#   inflating: faces/img_dataset/train/302.jpg
#   inflating: faces/img_dataset/train/585.jpg
#   inflating: faces/img_dataset/train/85.jpg
#   inflating: faces/img_dataset/train/437.jpg
#   inflating: faces/img_dataset/train/355.jpg
#   inflating: faces/img_dataset/train/69.jpg
#   inflating: faces/img_dataset/train/310.jpg
#   inflating: faces/img_dataset/train/509.jpg
#   inflating: faces/img_dataset/train/422.jpg
#   inflating: faces/img_dataset/train/476.jpg
#   inflating: faces/img_dataset/train/489.jpg
#   inflating: faces/img_dataset/train/448.jpg
#   inflating: faces/img_dataset/train/272.jpg
#   inflating: faces/img_dataset/train/616.jpg
#   inflating: faces/img_dataset/train/53.jpg
#   inflating: faces/img_dataset/train/158.jpg
#   inflating: faces/img_dataset/train/756.jpg
#   inflating: faces/img_dataset/train/390.jpg
#   inflating: faces/img_dataset/train/271.jpg
#   inflating: faces/img_dataset/train/255.jpg
#   inflating: faces/img_dataset/train/772.jpg
#   inflating: faces/img_dataset/train/901.jpg
#   inflating: faces/img_dataset/train/699.jpg
#   inflating: faces/img_dataset/train/43.jpg
#   inflating: faces/img_dataset/train/372.jpg
#   inflating: faces/img_dataset/train/25.jpg
#   inflating: faces/img_dataset/train/886.jpg
#   inflating: faces/img_dataset/train/797.jpg
#   inflating: faces/img_dataset/train/513.jpg
#   inflating: faces/img_dataset/train/374.jpg
#   inflating: faces/img_dataset/train/506.jpg
#   inflating: faces/img_dataset/train/823.jpg
#   inflating: faces/img_dataset/train/582.jpg
#   inflating: faces/img_dataset/train/456.jpg
#   inflating: faces/img_dataset/train/561.jpg
#   inflating: faces/img_dataset/train/12.jpg
#   inflating: faces/img_dataset/train/673.jpg
#   inflating: faces/img_dataset/train/597.jpg
#   inflating: faces/img_dataset/train/257.jpg
#   inflating: faces/img_dataset/train/758.jpg
#   inflating: faces/img_dataset/train/223.jpg
#   inflating: faces/img_dataset/train/40.jpg
#   inflating: faces/img_dataset/train/655.jpg
#   inflating: faces/img_dataset/train/205.jpg
#   inflating: faces/img_dataset/train/245.jpg
#   inflating: faces/img_dataset/train/206.jpg
#   inflating: faces/img_dataset/train/738.jpg
#   inflating: faces/img_dataset/train/552.jpg
#   inflating: faces/img_dataset/train/864.jpg
#   inflating: faces/img_dataset/train/295.jpg
#   inflating: faces/img_dataset/train/866.jpg
#   inflating: faces/img_dataset/train/663.jpg
#   inflating: faces/img_dataset/train/137.jpg
#   inflating: faces/img_dataset/train/667.jpg
#   inflating: faces/img_dataset/train/345.jpg
#   inflating: faces/img_dataset/train/642.jpg
#   inflating: faces/img_dataset/train/376.jpg
#   inflating: faces/img_dataset/train/761.jpg
#   inflating: faces/img_dataset/train/880.jpg
#   inflating: faces/img_dataset/train/857.jpg
#   inflating: faces/img_dataset/train/704.jpg
#   inflating: faces/img_dataset/train/318.jpg
#   inflating: faces/img_dataset/train/876.jpg
#   inflating: faces/img_dataset/train/393.jpg
#   inflating: faces/img_dataset/train/586.jpg
#   inflating: faces/img_dataset/train/779.jpg
#   inflating: faces/img_dataset/train/162.jpg
#   inflating: faces/img_dataset/train/593.jpg
#   inflating: faces/img_dataset/train/417.jpg
#   inflating: faces/img_dataset/train/217.jpg
#   inflating: faces/img_dataset/train/370.jpg
#   inflating: faces/img_dataset/train/794.jpg
#   inflating: faces/img_dataset/train/873.jpg
#   inflating: faces/img_dataset/train/143.jpg
#   inflating: faces/img_dataset/train/357.jpg
#   inflating: faces/img_dataset/train/340.jpg
#   inflating: faces/img_dataset/train/549.jpg
#   inflating: faces/img_dataset/train/198.jpg
#   inflating: faces/img_dataset/train/620.jpg
#   inflating: faces/img_dataset/train/599.jpg
#   inflating: faces/img_dataset/train/105.jpg
#   inflating: faces/img_dataset/train/210.jpg
#   inflating: faces/img_dataset/train/65.jpg
#   inflating: faces/img_dataset/train/142.jpg
#   inflating: faces/img_dataset/train/216.jpg
#   inflating: faces/img_dataset/train/687.jpg
#   inflating: faces/img_dataset/train/55.jpg
#   inflating: faces/img_dataset/train/457.jpg
#   inflating: faces/img_dataset/train/501.jpg
#   inflating: faces/img_dataset/train/286.jpg
#   inflating: faces/img_dataset/train/827.jpg
#   inflating: faces/img_dataset/train/289.jpg
#   inflating: faces/img_dataset/train/737.jpg
#   inflating: faces/img_dataset/train/491.jpg
#   inflating: faces/img_dataset/train/7.jpg
#   inflating: faces/img_dataset/train/231.jpg
#   inflating: faces/img_dataset/train/11.jpg
#   inflating: faces/img_dataset/train/284.jpg
#   inflating: faces/img_dataset/train/781.jpg
#   inflating: faces/img_dataset/train/343.jpg
#   inflating: faces/img_dataset/train/665.jpg
#   inflating: faces/img_dataset/train/825.jpg
#   inflating: faces/img_dataset/train/760.jpg
#   inflating: faces/img_dataset/train/319.jpg
#   inflating: faces/img_dataset/train/291.jpg
#   inflating: faces/img_dataset/train/314.jpg
#   inflating: faces/img_dataset/train/31.jpg
#   inflating: faces/img_dataset/train/117.jpg
#   inflating: faces/img_dataset/train/400.jpg
#   inflating: faces/img_dataset/train/405.jpg
#   inflating: faces/img_dataset/train/270.jpg
#   inflating: faces/img_dataset/train/34.jpg
#   inflating: faces/img_dataset/train/80.jpg
#   inflating: faces/img_dataset/train/669.jpg
#   inflating: faces/img_dataset/train/371.jpg
#   inflating: faces/img_dataset/train/26.jpg
#   inflating: faces/img_dataset/train/130.jpg
#   inflating: faces/img_dataset/train/268.jpg
#   inflating: faces/img_dataset/train/630.jpg
#   inflating: faces/img_dataset/train/354.jpg
#   inflating: faces/img_dataset/train/877.jpg
#   inflating: faces/img_dataset/train/765.jpg
#   inflating: faces/img_dataset/train/246.jpg
#   inflating: faces/img_dataset/train/851.jpg
#   inflating: faces/img_dataset/train/123.jpg
#   inflating: faces/img_dataset/train/861.jpg
#   inflating: faces/img_dataset/train/430.jpg
#   inflating: faces/img_dataset/train/732.jpg
#   inflating: faces/img_dataset/train/420.jpg
#   inflating: faces/img_dataset/train/368.jpg
#   inflating: faces/img_dataset/train/750.jpg
#   inflating: faces/img_dataset/train/96.jpg
#   inflating: faces/img_dataset/train/347.jpg
#   inflating: faces/img_dataset/train/394.jpg
#   inflating: faces/img_dataset/train/740.jpg
#   inflating: faces/img_dataset/train/68.jpg
#   inflating: faces/img_dataset/train/721.jpg
#   inflating: faces/img_dataset/train/82.jpg
#   inflating: faces/img_dataset/train/190.jpg
#   inflating: faces/img_dataset/train/565.jpg
#   inflating: faces/img_dataset/train/708.jpg
#   inflating: faces/img_dataset/train/899.jpg
#   inflating: faces/img_dataset/train/848.jpg
#   inflating: faces/img_dataset/train/410.jpg
#   inflating: faces/img_dataset/train/496.jpg
#   inflating: faces/img_dataset/train/151.jpg
#   inflating: faces/img_dataset/train/531.jpg
#   inflating: faces/img_dataset/train/795.jpg
#   inflating: faces/img_dataset/train/887.jpg
#   inflating: faces/img_dataset/train/283.jpg
#   inflating: faces/img_dataset/train/500.jpg
#   inflating: faces/img_dataset/train/563.jpg
#   inflating: faces/img_dataset/train/494.jpg
#   inflating: faces/img_dataset/train/276.jpg
#   inflating: faces/img_dataset/train/432.jpg
#   inflating: faces/img_dataset/train/146.jpg
#   inflating: faces/img_dataset/train/508.jpg
#   inflating: faces/img_dataset/train/778.jpg
#   inflating: faces/img_dataset/train/392.jpg
#   inflating: faces/img_dataset/train/792.jpg
#   inflating: faces/img_dataset/train/52.jpg
#   inflating: faces/img_dataset/train/166.jpg
#   inflating: faces/img_dataset/train/438.jpg
#   inflating: faces/img_dataset/train/895.jpg
#   inflating: faces/img_dataset/train/325.jpg
#   inflating: faces/img_dataset/train/748.jpg
#   inflating: faces/img_dataset/train/127.jpg
#   inflating: faces/img_dataset/train/680.jpg
#   inflating: faces/img_dataset/train/156.jpg
#   inflating: faces/img_dataset/train/677.jpg
#   inflating: faces/img_dataset/train/844.jpg
#   inflating: faces/img_dataset/train/18.jpg
#   inflating: faces/img_dataset/train/382.jpg
#   inflating: faces/img_dataset/train/686.jpg
#   inflating: faces/img_dataset/train/518.jpg
#   inflating: faces/img_dataset/train/113.jpg
#   inflating: faces/img_dataset/train/601.jpg
#   inflating: faces/img_dataset/train/180.jpg
#   inflating: faces/img_dataset/train/48.jpg
#   inflating: faces/img_dataset/train/260.jpg
#   inflating: faces/img_dataset/train/842.jpg
#   inflating: faces/img_dataset/train/682.jpg
#   inflating: faces/img_dataset/train/169.jpg
#   inflating: faces/img_dataset/train/131.jpg
#   inflating: faces/img_dataset/train/234.jpg
#   inflating: faces/img_dataset/train/236.jpg
#   inflating: faces/img_dataset/train/207.jpg
#   inflating: faces/img_dataset/train/148.jpg
#   inflating: faces/img_dataset/train/587.jpg
#   inflating: faces/img_dataset/train/365.jpg
#   inflating: faces/img_dataset/train/189.jpg
#   inflating: faces/img_dataset/train/720.jpg
#   inflating: faces/img_dataset/train/218.jpg
#   inflating: faces/img_dataset/train/423.jpg
#   inflating: faces/img_dataset/train/791.jpg
#   inflating: faces/img_dataset/train/698.jpg
#   inflating: faces/img_dataset/train/713.jpg
#   inflating: faces/img_dataset/train/606.jpg
#   inflating: faces/img_dataset/train/608.jpg
#   inflating: faces/img_dataset/train/139.jpg
#   inflating: faces/img_dataset/train/709.jpg
#   inflating: faces/img_dataset/train/344.jpg
#   inflating: faces/img_dataset/train/351.jpg
#   inflating: faces/img_dataset/train/239.jpg
#   inflating: faces/img_dataset/train/264.jpg
#   inflating: faces/img_dataset/train/37.jpg
#   inflating: faces/img_dataset/train/421.jpg
#   inflating: faces/img_dataset/train/333.jpg
#   inflating: faces/img_dataset/train/157.jpg
#   inflating: faces/img_dataset/train/809.jpg
#   inflating: faces/img_dataset/train/679.jpg
#   inflating: faces/img_dataset/train/691.jpg
#   inflating: faces/img_dataset/train/240.jpg
#   inflating: faces/img_dataset/train/373.jpg
#   inflating: faces/img_dataset/train/92.jpg
#   inflating: faces/img_dataset/train/645.jpg
#   inflating: faces/img_dataset/train/544.jpg
#   inflating: faces/img_dataset/train/329.jpg
#   inflating: faces/img_dataset/train/90.jpg
#   inflating: faces/img_dataset/train/634.jpg
#   inflating: faces/img_dataset/train/49.jpg
#   inflating: faces/img_dataset/train/482.jpg
#   inflating: faces/img_dataset/train/369.jpg
#   inflating: faces/img_dataset/train/450.jpg
#   inflating: faces/img_dataset/train/38.jpg
#   inflating: faces/img_dataset/train/39.jpg
#   inflating: faces/img_dataset/train/522.jpg
#   inflating: faces/img_dataset/train/651.jpg
#   inflating: faces/img_dataset/train/277.jpg
#   inflating: faces/img_dataset/train/807.jpg
#   inflating: faces/img_dataset/train/581.jpg
#   inflating: faces/img_dataset/train/109.jpg
#   inflating: faces/img_dataset/train/304.jpg
#   inflating: faces/img_dataset/train/871.jpg
#   inflating: faces/img_dataset/train/152.jpg
#   inflating: faces/img_dataset/train/307.jpg
#   inflating: faces/img_dataset/train/107.jpg
#   inflating: faces/img_dataset/train/875.jpg
#   inflating: faces/img_dataset/train/76.jpg
#   inflating: faces/img_dataset/train/244.jpg
#   inflating: faces/img_dataset/train/490.jpg
#   inflating: faces/img_dataset/train/786.jpg
#   inflating: faces/img_dataset/train/453.jpg
#   inflating: faces/img_dataset/train/868.jpg
#   inflating: faces/img_dataset/train/15.jpg
#   inflating: faces/img_dataset/train/401.jpg
#   inflating: faces/img_dataset/train/870.jpg
#   inflating: faces/img_dataset/train/600.jpg
#   inflating: faces/img_dataset/train/603.jpg
#   inflating: faces/img_dataset/train/135.jpg
#   inflating: faces/img_dataset/train/685.jpg
#   inflating: faces/img_dataset/train/445.jpg
#   inflating: faces/img_dataset/train/714.jpg
#   inflating: faces/img_dataset/train/532.jpg
#   inflating: faces/img_dataset/train/479.jpg
#   inflating: faces/img_dataset/train/538.jpg
#   inflating: faces/img_dataset/train/428.jpg
#   inflating: faces/img_dataset/train/225.jpg
#   inflating: faces/img_dataset/train/568.jpg
#   inflating: faces/img_dataset/train/890.jpg
#   inflating: faces/img_dataset/train/383.jpg
#   inflating: faces/img_dataset/train/16.jpg
#   inflating: faces/img_dataset/train/186.jpg
#   inflating: faces/img_dataset/train/36.jpg
#   inflating: faces/img_dataset/train/362.jpg
#   inflating: faces/img_dataset/train/98.jpg
#   inflating: faces/img_dataset/train/782.jpg
#   inflating: faces/img_dataset/train/444.jpg
#   inflating: faces/img_dataset/train/454.jpg
#   inflating: faces/img_dataset/train/101.jpg
#   inflating: faces/img_dataset/train/473.jpg
#   inflating: faces/img_dataset/train/670.jpg
#   inflating: faces/img_dataset/train/874.jpg
#   inflating: faces/img_dataset/train/24.jpg
#   inflating: faces/img_dataset/train/846.jpg
#   inflating: faces/img_dataset/train/724.jpg
#   inflating: faces/img_dataset/train/147.jpg
#   inflating: faces/img_dataset/train/439.jpg
#   inflating: faces/img_dataset/train/649.jpg
#   inflating: faces/img_dataset/train/66.jpg
#   inflating: faces/img_dataset/train/726.jpg
#   inflating: faces/img_dataset/train/643.jpg
#   inflating: faces/img_dataset/train/95.jpg
#   inflating: faces/img_dataset/train/251.jpg
#   inflating: faces/img_dataset/train/46.jpg
#   inflating: faces/img_dataset/train/550.jpg
#   inflating: faces/img_dataset/train/176.jpg
#   inflating: faces/img_dataset/train/118.jpg
#   inflating: faces/img_dataset/train/715.jpg
#   inflating: faces/img_dataset/train/647.jpg
#   inflating: faces/img_dataset/train/296.jpg
#   inflating: faces/img_dataset/train/472.jpg
#   inflating: faces/img_dataset/train/493.jpg
#   inflating: faces/img_dataset/train/72.jpg
#   inflating: faces/img_dataset/train/178.jpg
#   inflating: faces/img_dataset/train/855.jpg
#   inflating: faces/img_dataset/train/460.jpg
#   inflating: faces/img_dataset/train/822.jpg
#   inflating: faces/img_dataset/train/165.jpg
#   inflating: faces/img_dataset/train/539.jpg
#   inflating: faces/img_dataset/train/675.jpg
#   inflating: faces/img_dataset/train/124.jpg
#   inflating: faces/img_dataset/train/174.jpg
#   inflating: faces/img_dataset/train/75.jpg
#   inflating: faces/img_dataset/train/845.jpg
#   inflating: faces/img_dataset/train/263.jpg
#   inflating: faces/img_dataset/train/893.jpg
#   inflating: faces/img_dataset/train/56.jpg
#   inflating: faces/img_dataset/train/94.jpg
#   inflating: faces/img_dataset/train/208.jpg
#   inflating: faces/img_dataset/train/762.jpg
#   inflating: faces/img_dataset/train/144.jpg
#   inflating: faces/img_dataset/train/359.jpg
#   inflating: faces/img_dataset/train/470.jpg
#   inflating: faces/img_dataset/train/181.jpg
#   inflating: faces/img_dataset/train/161.jpg
#   inflating: faces/img_dataset/train/103.jpg
#   inflating: faces/img_dataset/train/826.jpg
#   inflating: faces/img_dataset/train/834.jpg
#   inflating: faces/img_dataset/train/187.jpg
#   inflating: faces/img_dataset/train/311.jpg
#   inflating: faces/img_dataset/train/247.jpg
#   inflating: faces/img_dataset/train/259.jpg
#   inflating: faces/img_dataset/train/829.jpg
#   inflating: faces/img_dataset/train/700.jpg
#   inflating: faces/img_dataset/train/604.jpg
#   inflating: faces/img_dataset/train/108.jpg
#   inflating: faces/img_dataset/train/327.jpg
#   inflating: faces/img_dataset/train/455.jpg
#   inflating: faces/img_dataset/train/249.jpg
#   inflating: faces/img_dataset/train/86.jpg
#   inflating: faces/img_dataset/train/138.jpg
#   inflating: faces/img_dataset/train/235.jpg
#   inflating: faces/img_dataset/train/852.jpg
#   inflating: faces/img_dataset/train/567.jpg
#   inflating: faces/img_dataset/train/200.jpg
#   inflating: faces/img_dataset/train/557.jpg
#   inflating: faces/img_dataset/train/412.jpg
#   inflating: faces/img_dataset/train/690.jpg
#   inflating: faces/img_dataset/train/671.jpg
#   inflating: faces/img_dataset/train/703.jpg
#   inflating: faces/img_dataset/train/817.jpg
#   inflating: faces/img_dataset/train/179.jpg
#   inflating: faces/img_dataset/train/224.jpg
#   inflating: faces/img_dataset/train/100.jpg
#   inflating: faces/img_dataset/train/122.jpg
#   inflating: faces/img_dataset/train/879.jpg
#   inflating: faces/img_dataset/train/783.jpg
#   inflating: faces/img_dataset/train/562.jpg
#   inflating: faces/img_dataset/train/171.jpg
#   inflating: faces/img_dataset/train/175.jpg
#   inflating: faces/img_dataset/train/452.jpg
#   inflating: faces/img_dataset/train/469.jpg
#   inflating: faces/img_dataset/train/209.jpg
#   inflating: faces/img_dataset/train/614.jpg
#   inflating: faces/img_dataset/train/678.jpg
#   inflating: faces/img_dataset/train/486.jpg
#   inflating: faces/img_dataset/train/746.jpg
#   inflating: faces/img_dataset/train/521.jpg
#   inflating: faces/img_dataset/train/321.jpg
#   inflating: faces/img_dataset/train/833.jpg
#   inflating: faces/img_dataset/train/8.jpg
#   inflating: faces/img_dataset/train/398.jpg
#   inflating: faces/img_dataset/train/228.jpg
#   inflating: faces/img_dataset/train/660.jpg
#   inflating: faces/img_dataset/train/869.jpg
#   inflating: faces/img_dataset/train/50.jpg
#   inflating: faces/img_dataset/train/710.jpg
#   inflating: faces/img_dataset/train/149.jpg
#   inflating: faces/img_dataset/train/341.jpg
#   inflating: faces/img_dataset/train/688.jpg
#   inflating: faces/img_dataset/train/167.jpg
#   inflating: faces/img_dataset/train/426.jpg
#   inflating: faces/img_dataset/train/33.jpg
#   inflating: faces/img_dataset/train/402.jpg
#   inflating: faces/img_dataset/train/674.jpg
#   inflating: faces/img_dataset/train/288.jpg
#   inflating: faces/img_dataset/train/443.jpg
#   inflating: faces/img_dataset/train/701.jpg
#   inflating: faces/img_dataset/train/433.jpg
#   inflating: faces/img_dataset/train/44.jpg
#   inflating: faces/img_dataset/train/474.jpg
#   inflating: faces/img_dataset/train/81.jpg
#   inflating: faces/img_dataset/train/775.jpg
#   inflating: faces/img_dataset/train/515.jpg
#   inflating: faces/img_dataset/train/202.jpg
#   inflating: faces/img_dataset/train/535.jpg
#   inflating: faces/img_dataset/train/856.jpg
#   inflating: faces/img_dataset/train/9.jpg
#   inflating: faces/img_dataset/train/312.jpg
#   inflating: faces/img_dataset/train/503.jpg
#   inflating: faces/img_dataset/train/70.jpg
#   inflating: faces/img_dataset/train/338.jpg
#   inflating: faces/img_dataset/train/253.jpg
#   inflating: faces/img_dataset/train/633.jpg
#   inflating: faces/img_dataset/train/650.jpg
#   inflating: faces/img_dataset/train/618.jpg
#   inflating: faces/img_dataset/train/584.jpg
#   inflating: faces/img_dataset/train/697.jpg
#   inflating: faces/img_dataset/train/819.jpg
#   inflating: faces/img_dataset/train/818.jpg
#   inflating: faces/img_dataset/train/888.jpg
#   inflating: faces/img_dataset/train/229.jpg
#   inflating: faces/img_dataset/train/306.jpg
#   inflating: faces/img_dataset/train/816.jpg
#   inflating: faces/img_dataset/train/154.jpg
#   inflating: faces/img_dataset/train/27.jpg
#   inflating: faces/img_dataset/train/523.jpg
#   inflating: faces/img_dataset/train/436.jpg
#   inflating: faces/img_dataset/train/348.jpg
#   inflating: faces/img_dataset/train/328.jpg
#   inflating: faces/img_dataset/train/502.jpg
#   inflating: faces/img_dataset/train/5.jpg
#   inflating: faces/img_dataset/train/814.jpg
#   inflating: faces/img_dataset/train/462.jpg
#   inflating: faces/img_dataset/train/356.jpg
#   inflating: faces/img_dataset/train/488.jpg
#   inflating: faces/img_dataset/train/511.jpg
#   inflating: faces/img_dataset/train/192.jpg
#   inflating: faces/img_dataset/train/722.jpg
#   inflating: faces/img_dataset/train/548.jpg
#   inflating: faces/img_dataset/train/591.jpg
#   inflating: faces/img_dataset/train/658.jpg
#   inflating: faces/img_dataset/train/883.jpg
#   inflating: faces/img_dataset/train/116.jpg
#   inflating: faces/img_dataset/train/872.jpg
#   inflating: faces/img_dataset/train/769.jpg
#   inflating: faces/img_dataset/train/389.jpg
#   inflating: faces/img_dataset/train/598.jpg
#   inflating: faces/img_dataset/train/300.jpg
#   inflating: faces/img_dataset/train/805.jpg
#   inflating: faces/img_dataset/train/624.jpg
#   inflating: faces/img_dataset/train/838.jpg
#   inflating: faces/img_dataset/train/896.jpg
#   inflating: faces/img_dataset/train/466.jpg
#   inflating: faces/img_dataset/train/733.jpg
#   inflating: faces/img_dataset/train/173.jpg
#   inflating: faces/img_dataset/train/514.jpg
#   inflating: faces/img_dataset/train/293.jpg
#   inflating: faces/img_dataset/train/892.jpg
#   inflating: faces/img_dataset/train/64.jpg
#   inflating: faces/img_dataset/train/358.jpg
#   inflating: faces/img_dataset/train/784.jpg
#   inflating: faces/img_dataset/train/396.jpg
#   inflating: faces/img_dataset/train/84.jpg
#   inflating: faces/img_dataset/train/860.jpg
#   inflating: faces/img_dataset/train/14.jpg
#   inflating: faces/img_dataset/train/129.jpg
#   inflating: faces/img_dataset/train/716.jpg
#   inflating: faces/img_dataset/train/796.jpg
#   inflating: faces/img_dataset/train/684.jpg
#   inflating: faces/img_dataset/train/278.jpg
#   inflating: faces/img_dataset/train/87.jpg
#   inflating: faces/img_dataset/train/706.jpg
#   inflating: faces/img_dataset/train/577.jpg
#   inflating: faces/img_dataset/train/570.jpg
#   inflating: faces/img_dataset/train/854.jpg
#   inflating: faces/img_dataset/train/799.jpg
#   inflating: faces/img_dataset/train/560.jpg
#   inflating: faces/img_dataset/train/589.jpg
#   inflating: faces/img_dataset/train/672.jpg
#   inflating: faces/img_dataset/train/487.jpg
#   inflating: faces/img_dataset/train/638.jpg
#   inflating: faces/img_dataset/train/902.jpg
#   inflating: faces/img_dataset/train/461.jpg
#   inflating: faces/img_dataset/train/681.jpg
#   inflating: faces/img_dataset/train/556.jpg
#   inflating: faces/img_dataset/train/554.jpg
#   inflating: faces/img_dataset/train/768.jpg
#   inflating: faces/img_dataset/train/232.jpg
#   inflating: faces/img_dataset/train/434.jpg
#   inflating: faces/img_dataset/train/804.jpg
#   inflating: faces/img_dataset/train/74.jpg
#   inflating: faces/img_dataset/train/418.jpg
#   inflating: faces/img_dataset/train/411.jpg
#   inflating: faces/img_dataset/train/806.jpg
#   inflating: faces/img_dataset/train/104.jpg
#   inflating: faces/img_dataset/train/505.jpg
#   inflating: faces/img_dataset/train/525.jpg
#   inflating: faces/img_dataset/train/10.jpg
#   inflating: faces/img_dataset/train/13.jpg
#   inflating: faces/img_dataset/train/885.jpg
#   inflating: faces/img_dataset/train/802.jpg
#   inflating: faces/img_dataset/train/801.jpg
#   inflating: faces/img_dataset/train/757.jpg
#   inflating: faces/img_dataset/train/898.jpg
#   inflating: faces/img_dataset/train/754.jpg
#   inflating: faces/img_dataset/train/611.jpg
#   inflating: faces/img_dataset/train/572.jpg
#   inflating: faces/img_dataset/train/712.jpg
#   inflating: faces/img_dataset/train/789.jpg
#   inflating: faces/img_dataset/train/360.jpg
#   inflating: faces/img_dataset/train/787.jpg
#   inflating: faces/img_dataset/train/414.jpg
#   inflating: faces/img_dataset/train/332.jpg
#   inflating: faces/img_dataset/train/613.jpg
#   inflating: faces/img_dataset/train/233.jpg
#   inflating: faces/img_dataset/train/404.jpg
#   inflating: faces/img_dataset/train/878.jpg
#   inflating: faces/img_dataset/train/388.jpg
#   inflating: faces/img_dataset/train/170.jpg
#   inflating: faces/img_dataset/train/326.jpg
#   inflating: faces/img_dataset/train/559.jpg
#   inflating: faces/img_dataset/train/467.jpg
#   inflating: faces/img_dataset/train/403.jpg
#   inflating: faces/img_dataset/train/274.jpg
#   inflating: faces/img_dataset/train/121.jpg
#   inflating: faces/img_dataset/train/431.jpg
#   inflating: faces/img_dataset/train/4.jpg
#   inflating: faces/img_dataset/train/395.jpg
#   inflating: faces/img_dataset/train/729.jpg
#   inflating: faces/img_dataset/train/759.jpg
#   inflating: faces/img_dataset/train/632.jpg
#   inflating: faces/img_dataset/train/385.jpg
#   inflating: faces/img_dataset/train/900.jpg
#   inflating: faces/img_dataset/train/361.jpg
#   inflating: faces/img_dataset/train/566.jpg
#   inflating: faces/img_dataset/train/201.jpg
#   inflating: faces/img_dataset/train/279.jpg
#   inflating: faces/img_dataset/train/894.jpg
#   inflating: faces/img_dataset/train/125.jpg
#   inflating: faces/img_dataset/train/20.jpg
#   inflating: faces/img_dataset/train/484.jpg
#   inflating: faces/img_dataset/train/196.jpg
#   inflating: faces/img_dataset/train/867.jpg
#   inflating: faces/img_dataset/train/865.jpg
#   inflating: faces/img_dataset/train/555.jpg
#   inflating: faces/img_dataset/train/364.jpg
#   inflating: faces/img_dataset/train/451.jpg
#   inflating: faces/img_dataset/train/60.jpg
#   inflating: faces/img_dataset/train/853.jpg
#   inflating: faces/img_dataset/train/408.jpg
#   inflating: faces/img_dataset/train/140.jpg
#   inflating: faces/img_dataset/train/299.jpg
#   inflating: faces/img_dataset/train/612.jpg
#   inflating: faces/img_dataset/train/483.jpg
#   inflating: faces/img_dataset/train/664.jpg
#   inflating: faces/img_dataset/train/497.jpg
#   inflating: faces/img_dataset/train/542.jpg
#   inflating: faces/img_dataset/train/63.jpg
#   inflating: faces/img_dataset/train/480.jpg
#   inflating: faces/img_dataset/train/641.jpg
#   inflating: faces/img_dataset/train/128.jpg
#   inflating: faces/img_dataset/train/547.jpg
#   inflating: faces/img_dataset/train/58.jpg
#   inflating: faces/img_dataset/train/350.jpg
#   inflating: faces/img_dataset/train/773.jpg
#   inflating: faces/img_dataset/train/808.jpg
#   inflating: faces/img_dataset/train/211.jpg
#   inflating: faces/img_dataset/train/313.jpg
#   inflating: faces/img_dataset/train/424.jpg
#   inflating: faces/img_dataset/train/429.jpg
#   inflating: faces/img_dataset/train/317.jpg
#   inflating: faces/img_dataset/train/576.jpg
#   inflating: faces/img_dataset/train/261.jpg
#   inflating: faces/img_dataset/train/553.jpg
#   inflating: faces/img_dataset/train/290.jpg
#   inflating: faces/img_dataset/train/6.jpg
#   inflating: faces/img_dataset/train/106.jpg
#   inflating: faces/img_dataset/train/835.jpg
#   inflating: faces/img_dataset/train/254.jpg
#   inflating: faces/img_dataset/train/17.jpg
#   inflating: faces/img_dataset/train/545.jpg
#   inflating: faces/img_dataset/train/335.jpg
#   inflating: faces/img_dataset/train/88.jpg
#   inflating: faces/img_dataset/train/399.jpg
#   inflating: faces/img_dataset/train/141.jpg
#   inflating: faces/img_dataset/train/745.jpg
#   inflating: faces/img_dataset/train/644.jpg
#   inflating: faces/img_dataset/train/322.jpg
#   inflating: faces/img_dataset/train/384.jpg
#   inflating: faces/img_dataset/train/891.jpg
#   inflating: faces/img_dataset/train/499.jpg
#   inflating: faces/img_dataset/train/840.jpg
#   inflating: faces/img_dataset/train/241.jpg
#   inflating: faces/img_dataset/train/409.jpg
#   inflating: faces/img_dataset/train/478.jpg
#   inflating: faces/img_dataset/train/850.jpg
#   inflating: faces/img_dataset/train/711.jpg
#   inflating: faces/img_dataset/train/707.jpg
#   inflating: faces/img_dataset/train/29.jpg
#   inflating: faces/img_dataset/train/692.jpg
#   inflating: faces/img_dataset/train/718.jpg
#   inflating: faces/img_dataset/train/541.jpg
#   inflating: faces/img_dataset/train/820.jpg
#   inflating: faces/img_dataset/train/267.jpg
#   inflating: faces/img_dataset/train/30.jpg
#   inflating: faces/img_dataset/train/413.jpg
#   inflating: faces/img_dataset/train/324.jpg
#   inflating: faces/img_dataset/train/579.jpg
#   inflating: faces/img_dataset/train/269.jpg
#   inflating: faces/img_dataset/train/889.jpg
#   inflating: faces/img_dataset/train/609.jpg
#   inflating: faces/img_dataset/train/380.jpg
#   inflating: faces/img_dataset/train/607.jpg
#   inflating: faces/img_dataset/train/546.jpg
#   inflating: faces/img_dataset/train/447.jpg
#   inflating: faces/img_dataset/train/811.jpg
#   inflating: faces/img_dataset/train/741.jpg
#   inflating: faces/img_dataset/train/770.jpg
#   inflating: faces/img_dataset/train/305.jpg
#   inflating: faces/img_dataset/train/168.jpg
#   inflating: faces/img_dataset/train/636.jpg
#   inflating: faces/img_dataset/train/648.jpg
#   inflating: faces/img_dataset/train/330.jpg
#   inflating: faces/img_dataset/train/668.jpg
#   inflating: faces/img_dataset/train/334.jpg
#   inflating: faces/img_dataset/train/659.jpg
#   inflating: faces/img_dataset/train/220.jpg
#   inflating: faces/img_dataset/train/222.jpg
#    creating: faces/polis_database/
#    creating: faces/polis_database/Brad/
#   inflating: faces/polis_database/Brad/brad.jpg
#    creating: faces/polis_database/dwayne/
#   inflating: faces/polis_database/dwayne/5d39af5836e03c45f92ffa85.jpg
#   inflating: faces/polis_database/dwayne/366x218-dwayne-johnson-kimdir-1516192234210.jpg
#   inflating: faces/polis_database/dwayne/The-Rock.jpg
#   inflating: faces/polis_database/dwayne/dwayne-the-rock-johnson-gty-jpo-180227_16x9_992.jpg
#   inflating: faces/polis_database/dwayne/Dwayne-Johnson-2.jpg
#   inflating: faces/polis_database/dwayne/rs_634x713-191203080056-634-dwayne-johnson-emd-120319.jpg
#   inflating: faces/polis_database/dwayne/d234a461cf593d3ea1eefc3f63db7074.jpg
#   inflating: faces/polis_database/dwayne/dwayne-johnson-attends-the-jumanji-the-next-level-uk-film-news-photo-1575726701.jpg
#   inflating: faces/polis_database/dwayne/dwayne-johnson-11818916-1-402.jpg
#   inflating: faces/polis_database/dwayne/dwayne-the-rock-johnson.jpg
#    creating: faces/polis_database/Rachel/
#   inflating: faces/polis_database/Rachel/Rachel.02.png
#   inflating: faces/polis_database/Rachel/Rachel19.jpg
#   inflating: faces/polis_database/Rachel/Rachel.05.png
#   inflating: faces/polis_database/Rachel/Rachel.04.png
#   inflating: faces/polis_database/Rachel/Rachel.03.png
#    creating: faces/polis_database/michael/
#   inflating: faces/polis_database/michael/mic222.jpg
#    creating: faces/polis_database/Chandler/
#   inflating: faces/polis_database/Chandler/Chandler.03.png
#  extracting: faces/polis_database/Chandler/Chandler.07.png
#   inflating: faces/polis_database/Chandler/Chandler15.jpg
#   inflating: faces/polis_database/Chandler/Chandler.02.png
#   inflating: faces/polis_database/Chandler/Chandler16.jpg
#   inflating: faces/polis_database/Chandler/Chandler19.jpg
#   inflating: faces/polis_database/Chandler/Chandler.09.png
#   inflating: faces/polis_database/Chandler/Chandler.08.png
#   inflating: faces/polis_database/Chandler/Chandler.05.png
#    creating: faces/polis_database/Trump/
#   inflating: faces/polis_database/Trump/donald-trump-is-pissed.jpg
#   inflating: faces/polis_database/Trump/11809114-3x2-700x467.jpg
#   inflating: faces/polis_database/Trump/TRUMP-GUATEMALA-1.jpg
#   inflating: faces/polis_database/Trump/Donald_Trump_official_portrait.jpg
#   inflating: faces/polis_database/Trump/lead_720_405.jpg
#   inflating: faces/polis_database/Trump/5ddeb349fd9db2065b3fc2b7.jpeg
#   inflating: faces/polis_database/Trump/shutterstock_editorial_10434333bm.jpg
#   inflating: faces/polis_database/Trump/donald-trump-11251.jpg
#   inflating: faces/polis_database/Trump/RTS2UO2L_0.jpg
#    creating: faces/polis_database/Monica/
#   inflating: faces/polis_database/Monica/Monica.05.png
#   inflating: faces/polis_database/Monica/Monica11.jpg
#   inflating: faces/polis_database/Monica/Monica.04.png
#   inflating: faces/polis_database/Monica/Monica8.jpg
#   inflating: faces/polis_database/Monica/Monica.02.png
#   inflating: faces/polis_database/Monica/Monica.08.png
#    creating: faces/polis_database/Barack Obama/
#   inflating: faces/polis_database/Barack Obama/3.jpg
#   inflating: faces/polis_database/Barack Obama/2.jpg
#   inflating: faces/polis_database/Barack Obama/12.jpg
#   inflating: faces/polis_database/Barack Obama/7.jpg
#   inflating: faces/polis_database/Barack Obama/11.jpg
#   inflating: faces/polis_database/Barack Obama/18.jpg
#   inflating: faces/polis_database/Barack Obama/15.jpg
#   inflating: faces/polis_database/Barack Obama/8.jpg
#   inflating: faces/polis_database/Barack Obama/9.jpg
#   inflating: faces/polis_database/Barack Obama/5.jpg
#   inflating: faces/polis_database/Barack Obama/10.jpg
#   inflating: faces/polis_database/Barack Obama/13.jpg
#   inflating: faces/polis_database/Barack Obama/4.jpg
#   inflating: faces/polis_database/Barack Obama/6.jpg
#   inflating: faces/polis_database/Barack Obama/1.jpg
#    creating: faces/polis_database/Pitt/
#   inflating: faces/polis_database/Pitt/im-132147.jpg
#   inflating: faces/polis_database/Pitt/brad-pitt-happy-56th-birthday-rex-ftr.jpg
#   inflating: faces/polis_database/Pitt/MV5BMjA1MjE2MTQ2MV5BMl5BanBnXkFtZTcwMjE5MDY0Nw@@._V1_.jpg
#   inflating: faces/polis_database/Pitt/brad-pitt-gettyimages-1175609064.jpg
#   inflating: faces/polis_database/Pitt/Brad_Pitt_2019_by_Glenn_Francis.jpg
#   inflating: faces/polis_database/Pitt/7WsFP6XTSEart0PsX_Q2Lg.jpg
#   inflating: faces/polis_database/Pitt/101936-521748706.jpg
#   inflating: faces/polis_database/Pitt/rs_600x600-191212115145-600x600-bradpitt-gj-12-12-19.jpg
#   inflating: faces/polis_database/Pitt/brad-pitt-attends-the-premiere-of-20th-century-foxs--square.jpg
#   inflating: faces/polis_database/Pitt/brad-pitt-ad-astra-tokyo-getty.jpg
#    creating: faces/polis_database/jolie/
#   inflating: faces/polis_database/jolie/07628640ab8a3422227ee1c6d5a11975.jpg
#   inflating: faces/polis_database/jolie/thVXD_1573028958_4681.jpg
#   inflating: faces/polis_database/jolie/tpTNg_1576915253_5616.jpg
#   inflating: faces/polis_database/jolie/MV5BODg3MzYwMjE4N15BMl5BanBnXkFtZTcwMjU5NzAzNw@@._V1_.jpg
#   inflating: faces/polis_database/jolie/angelina-jolie-struggling-to-let-go-of-resentment-against-brad-pitt-their-failed-marriage-ftr.jpg
#   inflating: faces/polis_database/jolie/Angelina_Jolie_2_June_2014_(cropped).jpg
#   inflating: faces/polis_database/jolie/bigstock-Angelina-Jolie.jpg
#   inflating: faces/polis_database/jolie/5c260959c03c0e04e478695d.jpg
#    creating: faces/polis_database/Johnson/
#   inflating: faces/polis_database/Johnson/johnson.jpg
#    creating: faces/polis_database/melina/
#   inflating: faces/polis_database/melina/me.jpg
#    creating: faces/polis_database/Thompson/
#   inflating: faces/polis_database/Thompson/111.jpg
#    creating: faces/polis_database/Jack/
#   inflating: faces/polis_database/Jack/574.jpg
#    creating: faces/polis_database/diCaprio/
#   inflating: faces/polis_database/diCaprio/rs_600x600-191130073825-600.leonardo-dicaprio.cm.113019.jpg
#   inflating: faces/polis_database/diCaprio/220px-Leonardo_Dicaprio_Cannes_2019.jpg
#   inflating: faces/polis_database/diCaprio/MV5BMjI0MTg3MzI0M15BMl5BanBnXkFtZTcwMzQyODU2Mw@@._V1_UY317_CR10,0,214,317_AL_.jpg
#   inflating: faces/polis_database/diCaprio/455886166.jpg
#   inflating: faces/polis_database/diCaprio/1504171650-leonardo-dicaprio-donation.jpg
#   inflating: faces/polis_database/diCaprio/leonardo_dicaprioya_kara_para_sorgusu_1472653068_8789.jpg
#   inflating: faces/polis_database/diCaprio/leonardo-dicaprio-1024x512.png
#   inflating: faces/polis_database/diCaprio/leonardo-dicaprio-greta-thunberg-1.jpg
#    creating: faces/polis_database/Chan/
#   inflating: faces/polis_database/Chan/jackie-chan-9542080-1-402.jpg
#   inflating: faces/polis_database/Chan/jackie-chan-medium.jpg
#   inflating: faces/polis_database/Chan/ST_20181201_JACKIECHAN_4452970.jpg
#   inflating: faces/polis_database/Chan/Jackie-Chan-Contact-Information.jpg
#   inflating: faces/polis_database/Chan/109721.jpg
#   inflating: faces/polis_database/Chan/122.jpg
#   inflating: faces/polis_database/Chan/Jackie_Chan.jpg
#   inflating: faces/polis_database/Chan/1.jpg
#    creating: faces/polis_database/Tom/
#   inflating: faces/polis_database/Tom/tom-cruise.jpg
#   inflating: faces/polis_database/Tom/Tom_Cruise_avp_2014_4.jpg
#   inflating: faces/polis_database/Tom/happy_birthday_tom_cruise_0_0.jpg
#   inflating: faces/polis_database/Tom/5df796fa79d75734ed61aa32.jpg
#   inflating: faces/polis_database/Tom/tom_cruise_gettyimages-1191503705.jpg
#   inflating: faces/polis_database/Tom/tom-cruise-9262645-1-402.jpg
#   inflating: faces/polis_database/Tom/MV5BMTk1MjM3NTU5M15BMl5BanBnXkFtZTcwMTMyMjAyMg@@._V1_UY1200_CR142,0,630,1200_AL_.jpg
#   inflating: faces/polis_database/Tom/640px-Tom_Cruise_in_London,_2015_(cropped).jpg
#   inflating: faces/polis_database/Tom/099529.jpg
#   inflating: faces/polis_database/Tom/tom-cruise-too-old-for-jack-reacher.jpg
#   inflating: faces/polis_database/Tom/maxresdefault.jpg
#    creating: faces/polis_database/James/
#   inflating: faces/polis_database/James/James.jpg
#    creating: faces/polis_database/Ross/
#   inflating: faces/polis_database/Ross/Ross04.png
#   inflating: faces/polis_database/Ross/ross12.png
#   inflating: faces/polis_database/Ross/ross09.jpg
#    creating: faces/polis_database/Joey/
#   inflating: faces/polis_database/Joey/Joey.05.png
#   inflating: faces/polis_database/Joey/Joey.03.png
#   inflating: faces/polis_database/Joey/Joey.08.png
#   inflating: faces/polis_database/Joey/Joey.04.png
#    creating: faces/polis_database/Phoebe/
#   inflating: faces/polis_database/Phoebe/Pheobe20.png
#   inflating: faces/polis_database/Phoebe/Pheobe09.jpg
#   inflating: faces/polis_database/Phoebe/Phoebe.03.png
#   inflating: faces/polis_database/Phoebe/Pheobe07.jpg
#   inflating: faces/polis_database/Phoebe/Phoebe.02.png
#   inflating: faces/polis_database/Phoebe/Pheobe11.jpg
#    creating: faces/polis_database/Lopez/
#   inflating: faces/polis_database/Lopez/owen-wilson-and-jennifer-lopez-on-location-for-marry-me-on-news-photo-1571774327.jpg
#   inflating: faces/polis_database/Lopez/cb86ead6ba2d66235117d799a1d25b01.jpg
#   inflating: faces/polis_database/Lopez/TIFF_2019_jlo_(1_of_1)-2_(48696671561)_(cropped).jpg
#   inflating: faces/polis_database/Lopez/jennifer-lopez-9542231-3-402.jpg
#   inflating: faces/polis_database/Lopez/3535371.jpg
#   inflating: faces/polis_database/Lopez/Jennifer_Lopez_at_GLAAD_Media_Awards_(cropped).jpg
#   inflating: faces/polis_database/Lopez/111219-jennifer-lopez-lead.jpg

# %%
import torch.nn as nn
import os
import torch
import torch.nn.functional as F
import time
import torchvision.transforms as transform
import torchvision.datasets as dtst
import torch.utils as utils
import pickle
import cv2
from matplotlib import pyplot
from keras.layers import Flatten, Dense, Input, GlobalAveragePooling2D, \
    GlobalMaxPooling2D, Activation, Conv2D, MaxPooling2D, BatchNormalization, \
    AveragePooling2D
from keras.utils.data_utils import get_file
from keras.models import Model
from keras import layers
from keras.preprocessing import image
import numpy as np
from scipy.spatial.distance import cosine
from  torch.autograd import Variable
import itertools




class uretici_ag(nn.Module):
#   agin genel yapisi
    def __init__(self, d=64):
        super(uretici_ag, self).__init__()
        # U-NET tabanli yapi 
        # Konvolusyonlu Kucultme 
        self.konvolusyon1 = nn.Conv2d(3, d, 4, 2, 1)
        self.konvolusyon2 = nn.Conv2d(d, d * 2, 4, 2, 1)
        self.konvolusyon2_batch = nn.BatchNorm2d(d * 2)
        self.konvolusyon3 = nn.Conv2d(d * 2, d * 4, 4, 2, 1)
        self.konvolusyon3_batch = nn.BatchNorm2d(d * 4)
        self.konvolusyon4 = nn.Conv2d(d * 4, d * 8, 4, 2, 1)
        self.konvolusyon4_batch = nn.BatchNorm2d(d * 8)
        self.konvolusyon5 = nn.Conv2d(d * 8, d * 8, 4, 2, 1)
        self.konvolusyon5_batch = nn.BatchNorm2d(d * 8)
        self.konvolusyon6= nn.Conv2d(d * 8, d * 8, 4, 2, 1)
        self.konvolusyon6_batch = nn.BatchNorm2d(d * 8)
        self.konvolusyon7= nn.Conv2d(d * 8, d * 8, 4, 2, 1)
        self.konvolusyon7_batch= nn.BatchNorm2d(d * 8)
        self.konvolusyon8= nn.Conv2d(d * 8, d * 8, 4, 2, 1)
        # self.conv8_bn = nn.BatchNorm2d(d * 8)

        # Ters Konvolusyon (Transpoze Konvolusyonlu Buyultme)
        self.ters_konvolusyon1 = nn.ConvTranspose2d(d * 8, d * 8, 4, 2, 1)
        self.ters_konvolusyon1_batch = nn.BatchNorm2d(d * 8)
        self.ters_konvolusyon2= nn.ConvTranspose2d(d * 8 * 2, d * 8, 4, 2, 1)
        self.ters_konvolusyon2_batch = nn.BatchNorm2d(d * 8)
        self.ters_konvolusyon3= nn.ConvTranspose2d(d * 8 * 2, d * 8, 4, 2, 1)
        self.ters_konvolusyon3_batch= nn.BatchNorm2d(d * 8)
        self.ters_konvolusyon4= nn.ConvTranspose2d(d * 8 * 2, d * 8, 4, 2, 1)
        self.ters_konvolusyon4_batch= nn.BatchNorm2d(d * 8)
        self.ters_konvolusyon5= nn.ConvTranspose2d(d * 8 * 2, d * 4, 4, 2, 1)
        self.ters_konvolusyon5_batch= nn.BatchNorm2d(d * 4)
        self.ters_konvolusyon6= nn.ConvTranspose2d(d * 4 * 2, d * 2, 4, 2, 1)
        self.ters_konvolusyon6_batch= nn.BatchNorm2d(d * 2)
        self.ters_konvolusyon7= nn.ConvTranspose2d(d * 2 * 2, d, 4, 2, 1)
        self.ters_konvolusyon7_batch= nn.BatchNorm2d(d)
        self.ters_konvolusyon8= nn.ConvTranspose2d(d * 2, 3, 4, 2, 1)

    # Kitle (Matrisin ilkin katsayilarinin ayarlanmasi)
    def _katsayi_ayarla_ag_(self, ortalama, standart_sapma):
        for m in self._modules:
            katsayi_ayarlama(self._modules[m], ortalama, standart_sapma)

    # forward method
    def forward(self, girdi):
      # Bu kisimda yayindada belirtildigi gibi U-Net agini kurmaya basliyoruz
        e1 = self.konvolusyon1(girdi)
        e2 = self.konvolusyon2_batch(self.konvolusyon2(F.leaky_relu(e1, 0.2)))
        e3 = self.konvolusyon3_batch(self.konvolusyon3(F.leaky_relu(e2, 0.2)))
        e4 = self.konvolusyon4_batch(self.konvolusyon4(F.leaky_relu(e3, 0.2)))
        e5 = self.konvolusyon5_batch(self.konvolusyon5(F.leaky_relu(e4, 0.2)))
        e6 = self.konvolusyon6_batch(self.konvolusyon6(F.leaky_relu(e5, 0.2)))
        e7 = self.konvolusyon7_batch(self.konvolusyon7(F.leaky_relu(e6, 0.2)))
        e8 = self.konvolusyon8(F.leaky_relu(e7, 0.2))

        
        d1 = F.dropout(self.ters_konvolusyon1_batch(self.ters_konvolusyon1(F.relu(e8))), 0.5, training=True)
        d1 = torch.cat([d1, e7], 1)
        d2 = F.dropout(self.ters_konvolusyon2_batch(self.ters_konvolusyon2(F.relu(d1))), 0.5, training=True)
        d2 = torch.cat([d2, e6], 1)
        d3 = F.dropout(self.ters_konvolusyon3_batch(self.ters_konvolusyon3(F.relu(d2))), 0.5, training=True)
        d3 = torch.cat([d3, e5], 1)
        d4 = self.ters_konvolusyon4_batch(self.ters_konvolusyon4(F.relu(d3)))
        # d4 = F.dropout(self.deconv4_bn(self.deconv4(F.relu(d3))), 0.5)
        d4 = torch.cat([d4, e4], 1)
        d5 = self.ters_konvolusyon5_batch(self.ters_konvolusyon5(F.relu(d4)))
        d5 = torch.cat([d5, e3], 1)
        d6 = self.ters_konvolusyon6_batch(self.ters_konvolusyon6(F.relu(d5)))
        d6 = torch.cat([d6, e2], 1)
        d7 = self.ters_konvolusyon7_batch(self.ters_konvolusyon7(F.relu(d6)))
        d7 = torch.cat([d7, e1], 1)
        d8 = self.ters_konvolusyon8(F.relu(d7))
        o = F.tanh(d8)

        return o

class ayirt_edici_ag(nn.Module):
    # genel ayirt edici ag yapisi
    def __init__(self, d=64):
        super(ayirt_edici_ag, self).__init__()
        self.konvolusyon1 = nn.Conv2d(6, d, 4, 2, 1)
        self.konvolusyon2 = nn.Conv2d(d, d * 2, 4, 2, 1)
        self.konvolusyon2_batch = nn.BatchNorm2d(d * 2)
        self.konvolusyon3 = nn.Conv2d(d * 2, d * 4, 4, 2, 1)
        self.konvolusyon3_batch = nn.BatchNorm2d(d * 4)
        self.konvolusyon4= nn.Conv2d(d * 4, d * 8, 4, 1, 1)
        self.konvolusyon4_batch = nn.BatchNorm2d(d * 8)
        self.konvolusyon5 = nn.Conv2d(d * 8, 1, 4, 1, 1)

    # agin katsayilarinin ayarlanmasi 
    def _katsayi_ayarla_ag_(self, ortalama, standart_sapma):
        for m in self._modules:
            katsayi_ayarlama(self._modules[m], ortalama, standart_sapma)

    # girdi-cikti methodu (forward-pass)
    def forward(self, girdi, cevap):
        x = torch.cat([girdi, cevap], 1)
        x = F.leaky_relu(self.konvolusyon1(x), 0.2)
        x = F.leaky_relu(self.konvolusyon2_batch(self.konvolusyon2(x)), 0.2)
        x = F.leaky_relu(self.konvolusyon3_batch(self.konvolusyon3(x)), 0.2)
        x = F.leaky_relu(self.konvolusyon4_batch(self.konvolusyon4(x)), 0.2)
        x = F.sigmoid(self.konvolusyon5(x))

        return x

def katsayi_ayarlama(katman, ortalama, standart_sapma):
  # Sadece ve Sadece verilen katman Konvolusyon ise o zaman katsayilari ayarla
  # normal dagilima gore ayarlama yap!
    if isinstance(katman, nn.ConvTranspose2d) or isinstance(katman, nn.Conv2d):
        katman.weight.data.normal_(ortalama, standart_sapma)
        katman.bias.data.zero_()

# fotograflari torchun anlaya bilicegi sekilde duzenleyip tensor formuna salalim
def dataloader_hazirla():
    transformation=transform.Compose([transform.ToTensor(),transform.Normalize(mean=[0.5,0.5,0.5],std=[0.5,0.5,0.5])])
    traindata=dtst.ImageFolder(root="./faces/img_dataset/",transform=transformation)
    traindataloader=utils.data.DataLoader(traindata,batch_size=10,shuffle=True,num_workers=4)
    return traindataloader

uretici=uretici_ag()
ayirtedici=ayirt_edici_ag()
uretici._katsayi_ayarla_ag_(ortalama=0.0, standart_sapma=0.02)
ayirtedici._katsayi_ayarla_ag_(ortalama=0.0, standart_sapma=0.02)
uretici.cuda()
ayirtedici.cuda()
uretici.train()
ayirtedici.train()


uretici_optimizer=torch.optim.Adam(uretici.parameters(),lr=0.0002,betas=[0.5,0.999])
ayirtedici_optimizer=torch.optim.Adam(ayirtedici.parameters(),lr=0.0002,betas=[0.5,0.999])
hata1=torch.nn.BCELoss().cuda()
hata2=torch.nn.L1Loss().cuda()


def goster(G, kaydet= 'sonuc_foto.png'):
    pyplot.imshow((G[0].cpu().data.numpy().transpose(1, 2, 0) + 1) / 2)
    pyplot.savefig(kaydet,bbox_inches='tight', pad_inches=0,transparent=True)
    pyplot.show()



dataloader=dataloader_hazirla()
transformation=transform.Compose([transform.Resize((256,256)),transform.ToTensor(),transform.Normalize(mean=[0.5,0.5,0.5],std=[0.5,0.5,0.5])])
test=dtst.ImageFolder(root="./faces/arama",transform=transformation)
test=utils.data.DataLoader(test,batch_size=1,shuffle=True,num_workers=4)
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
##############################################################################################
#                             Egitim Kismi
##############################################################################################

#   Pi2Pix aginin egitimi icin bu bloku calistirmak gerekmektedir
#   Bu blok calistiktan sonra her 10 iterasyonda test icin arama klasorundeki
#   Fotolar uretilmeye baslayacak ve gosterilecektir 
#   Eger hazir katsayilardan egitim yapilmadan test edilmek isteniyorsa
#   Diger bu blogu *calistirmadan diger blogu direk calistirin 
#   Iyi sonuclar gore bilmek icin agi en az 2 saat calistirmak gerekiyor 
#   Ortalama sonuc icin 90 devir yeterlidir
#   Cok daha gercekci sonuclar icin en az 1-2 gun calistirma oneriliyor  

for devir_sayisi in range(30):
    iterasyon_sayac=0
    for resim, _ in dataloader:
        # ayirtedici agin gradientlerini sifirla
        ayirtedici.zero_grad()
        # sadece cizilmis resmi al 
        cikti = resim[:, :, :, 0:256]
        girdi = resim[:, :, :, 256:]
        
        girdi, cikti = Variable(girdi.cuda()), Variable(cikti.cuda())

        # Ayirt edici agi egit
        ayirt_edici_cikti = ayirtedici(girdi, cikti).squeeze()
        ayirt_edici_hata1 = hata1(ayirt_edici_cikti, Variable(torch.ones(ayirt_edici_cikti.size()).cuda()))

        uretici_cikti = uretici(girdi)
        ayirt_edici_cikti = ayirtedici(girdi, uretici_cikti).squeeze()
        ayirt_edici_hata2 = hata1(ayirt_edici_cikti, Variable(torch.zeros(ayirt_edici_cikti.size()).cuda()))

        ayirt_edici_toplam_hata = (ayirt_edici_hata1 + ayirt_edici_hata2) * 0.5
        ayirt_edici_toplam_hata.backward()
        ayirtedici_optimizer.step()



        # Uretici agin egitimi
        uretici.zero_grad()
        uretici_cikti = uretici(girdi)
        ayirt_edici_cikti = ayirtedici(girdi, uretici_cikti).squeeze()
        uretici_hata = hata1(ayirt_edici_cikti, Variable(torch.ones(ayirt_edici_cikti.size()).cuda())) + 100 * hata2(uretici_cikti, cikti)
        uretici_hata.backward()
        uretici_optimizer.step()

        iterasyon_sayac+= 1
        if(iterasyon_sayac%10==0):
          img=next(iter(test))
          print(iterasyon_sayac)
          goster(uretici(Variable(img[0]).to(device="cuda",dtype=torch.float)))
    print("Ag parametreleri ve katsayilari kaydediliyor")
    print(devir)
    torch.save(uretici.state_dict(), './uretici.pkl')
    torch.save(ayirtedici.state_dict(), './ayirt_edici.pkl')
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1351: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1340: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# 10
# 20
# 30
# 40
# 50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-6d039f6c3ab6> in <module>()
#      35         iterasyon_sayac+= 1
#      36         if(iterasyon_sayac%10==0):
# ---> 37           img=next(iter(test))
#      38           print(iterasyon_sayac)
#      39           goster(uretici(Variable(img[0]).to(device="cuda",dtype=torch.float)))
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py in __iter__(self)
#     276             return _SingleProcessDataLoaderIter(self)
#     277         else:
# --> 278             return _MultiProcessingDataLoaderIter(self)
#     279
#     280     @property
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py in __init__(self, loader)
#     680             #     before it starts, and __del__ tries to join but will get:
#     681             #     AssertionError: can only join a started process.
# --> 682             w.start()
#     683             self._index_queues.append(index_queue)
#     684             self._workers.append(w)
#
# /usr/lib/python3.6/multiprocessing/process.py in start(self)
#     103                'daemonic processes are not allowed to have children'
#     104         _cleanup()
# --> 105         self._popen = self._Popen(self)
#     106         self._sentinel = self._popen.sentinel
#     107         # Avoid a refcycle if the target function holds an indirect
#
# /usr/lib/python3.6/multiprocessing/context.py in _Popen(process_obj)
#     221     @staticmethod
#     222     def _Popen(process_obj):
# --> 223         return _default_context.get_context().Process._Popen(process_obj)
#     224
#     225 class DefaultContext(BaseContext):
#
# /usr/lib/python3.6/multiprocessing/context.py in _Popen(process_obj)
#     275         def _Popen(process_obj):
#     276             from .popen_fork import Popen
# --> 277             return Popen(process_obj)
#     278
#     279     class SpawnProcess(process.BaseProcess):
#
# /usr/lib/python3.6/multiprocessing/popen_fork.py in __init__(self, process_obj)
#      17         util._flush_std_streams()
#      18         self.returncode = None
# ---> 19         self._launch(process_obj)
#      20
#      21     def duplicate_for_child(self, fd):
#
# /usr/lib/python3.6/multiprocessing/popen_fork.py in _launch(self, process_obj)
#      64         code = 1
#      65         parent_r, child_w = os.pipe()
# ---> 66         self.pid = os.fork()
#      67         if self.pid == 0:
#      68             try:
#
# KeyboardInterrupt:

# %%
################################################################################
#                     Hazir daha once egitimi yapilmis katsayilari yuklemek
#                     icin bu blok , eger yukardaki blokla egitim yapiliyorsa
#               ******bu blok-un calistirilmasina ihtiyac yoktur
################################################################################
uretici=uretici_ag()
katsayilar=torch.load("uretici.pkl")
uretici.load_state_dict(katsayilar)
uretici=uretici.cuda()

# %%
sayac=0
for foto,counter in test:
  res=uretici(Variable(foto).cuda())
  print(res.shape)
  sayac+=1
  goster(res,kaydet=str(sayac)+".jpg")
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1340: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])

# %%
def Normal_Blok(girdi_tensor, kernel_boyutu, katmanlar,
                          bias=False):
    katman1, katman2, katman3 = katmanlar

    x = Conv2D(katman1, (1, 1), use_bias=bias,)(
        girdi_tensor)
    x = BatchNormalization(axis=3)(x)
    x = Activation('relu')(x)

    x = Conv2D(katman2, kernel_boyutu, use_bias=bias,
               padding='same')(x)
    x = BatchNormalization(axis=3)(x)
    x = Activation('relu')(x)

    x = Conv2D(katman3, (1, 1), use_bias=bias)(x)
    x = BatchNormalization(axis=3)(x)

    # Burada katmanlar birlestiriliyor
    x = layers.add([x, girdi_tensor])
    x = Activation('relu')(x)
    return x


def Resnet_Blok(girdi_tensor, kernel_boyutu, katmanlar,
                      stride=(2, 2), bias=False):
    katman1,katman2,katman3=katmanlar
    
    x = Conv2D(katman1, (1, 1), strides=stride, use_bias=bias
               )(girdi_tensor)
    x = BatchNormalization(axis=3)(x)
    x = Activation('relu')(x)

    x = Conv2D(katman2, kernel_boyutu, padding='same', use_bias=bias,
               )(x)
    x = BatchNormalization(axis=3)(x)
    x = Activation('relu')(x)

    x = Conv2D(katman3, (1, 1),  use_bias=bias)(x)
    x = BatchNormalization(axis=3)(x)

    katman_hafizasi = Conv2D(katman3, (1, 1), strides=stride, use_bias=bias,
                      )(girdi_tensor)
    katman_hafizasi = BatchNormalization(axis=3)(
        katman_hafizasi)

    x = layers.add([x, katman_hafizasi])
    x = Activation('relu')(x)
    return x


def RESNET50():
    girdi_boyutu = (224,224,3)

    foto_girdi =Input(tensor=None, shape=girdi_boyutu)

    print("Girdi boyutlari: {}",girdi_boyutu)
    x = Conv2D(
        64, (7,7), use_bias=False, strides=(2, 2), padding='same'
      )(foto_girdi)

    x = BatchNormalization(axis=3)(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((3, 3), strides=(2, 2))(x)
    print("Ilk blok cikti boyutlari: {}",x.shape)


    x = Resnet_Blok(x, 3, [64, 64, 256],stride=(1, 1))
    print("Ikinci Blok boyutlari: {}",x.shape)
    x = Normal_Blok(x, 3, [64, 64, 256])
    print("Ucuncu Blok boyutlari: {}",x.shape)
    x = Normal_Blok(x, 3, [64, 64, 256])
    print("Dorduncu Blok boyutlari: {}",x.shape)
    x = Resnet_Blok(x, 3, [128, 128, 512])
    print("Besinci Blok boyutlari: {}",x.shape)
    x = Normal_Blok(x, 3, [128, 128, 512])
    print("Altinci Blok boyutlari: {}",x.shape)
    x = Normal_Blok(x, 3, [128, 128, 512])
    print("Yedinci Blok boyutlari: {}",x.shape)
    x = Normal_Blok(x, 3, [128, 128, 512])
    print("Sekizinci Blok boyutlari: {}",x.shape)
####
    x = Resnet_Blok(x, 3, [256, 256, 1024])
    print("Dokuzuncu Blok boyutlari: {}",x.shape)

    x = Normal_Blok(x, 3, [256, 256, 1024])
    print("Onuncu Blok boyutlari: {}",x.shape)
    x = Normal_Blok(x, 3, [256, 256, 1024])
    print("Onbirinci Blok boyutlari: {}",x.shape)
    x = Normal_Blok(x, 3, [256, 256, 1024])
    print("Onikinci Blok boyutlari: {}",x.shape)
    x = Normal_Blok(x, 3, [256, 256, 1024])
    print("Onucuncu Blok boyutlari: {}",x.shape)
    x = Normal_Blok(x, 3, [256, 256, 1024])
    print("Ondorduncu Blok boyutlari: {}",x.shape)
####
    x = Resnet_Blok(x, 3, [512, 512, 2048])
    print("Onbesinci Blok boyutlari: {}",x.shape)
    x = Normal_Blok(x, 3, [512, 512, 2048])
    print("Onaltinci Blok boyutlari: {}",x.shape)
    x = Normal_Blok(x, 3, [512, 512, 2048])
    print("Onyedinci Blok boyutlari: {}",x.shape)
    x = AveragePooling2D((7, 7))(x)
    x = GlobalMaxPooling2D()(x)
    print("Son Blok boyutlari: {}",x.shape)

    model = Model(foto_girdi, x, name='vggface_resnet50')
    weights_path = get_file('rcmalli_vggface_tf_notop_resnet50.h5',
                                    'https://github.com/rcmalli/keras-vggface/releases/download/v2.0/rcmalli_vggface_tf_notop_resnet50.h5',
                                    cache_subdir='./')
            
    model.load_weights(weights_path)
    return model

# %%
Aranan_ag_ciktisi="6.jpg"

# %%
model=RESNET50()

import cv2
aranan_kisi = image.load_img(Aranan_ag_ciktisi,(224, 224))

x = image.img_to_array(aranan_kisi)
x=x[16:241,16:241]
pyplot.imshow(x/255)
pyplot.show()
x=cv2.resize(x,(190,190))
x=cv2.resize(x,(224,224))

x = np.expand_dims(x, axis=0)
aranan_kisi=model.predict(x)


folder="./faces/polis_database/"
dirs=os.listdir(folder)

final_skorlari={}



for dir in dirs:
  imgs=os.listdir(folder+dir)
  scores=[]
  for img in imgs:
    img = image.load_img(folder+dir+"/"+img)
    x = image.img_to_array(img)
    x=cv2.resize(x,(190,190))
    x=cv2.resize(x,(224,224))
    x = np.expand_dims(x, axis=0)
    res1=model.predict(x)
    scores.append(1-cosine(res1[0],aranan_kisi[0]))
  final_skorlari[max(scores)]=dir

maxs=[x for x in sorted(final_skorlari.keys(),reverse=True)]
final=[]
for x in range(3):
  imgs=os.listdir("./faces/polis_database/"+final_skorlari[maxs[x]])
  final.append(pyplot.imread("./faces/polis_database/"+final_skorlari[maxs[x]]+"/"+imgs[0]))



print("En benzer fotolar ve benzerlik skorlari")
pyplot.subplot(131)
pyplot.imshow(final[0])
print("Benzerlik skoru : {} isim : {}".format(maxs[0],final_skorlari[maxs[0]]))
pyplot.subplot(132)
pyplot.imshow(final[1])
print("Benzerlik skoru : {} isim : {}".format(maxs[1],final_skorlari[maxs[1]]))
pyplot.subplot(133)
pyplot.imshow(final[2])
print("Benzerlik skoru : {} isim : {}".format(maxs[2],final_skorlari[maxs[2]]))
pyplot.show()

# %%
final_skorlari
